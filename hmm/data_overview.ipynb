# %%
from Bio import SeqIO
from Bio.Seq import Seq
from Bio.SeqRecord import SeqRecord
import os
import pandas as pd

# %%
df = pd.read_csv("/zhouyuyang/project/ProteinFeatureEngineering/data/all.csv")
df['number'] = None
df.columns
# Out:
# Index(['Class', 'Familiy/genus', 'protein name', 'FP', 'file name', 'number'], dtype='object')

# %%
family_name = None
protein_name = None
records = None
cnt = 0
protein_cnt = 0
for _, row in df.iterrows():
    if type(row['FP']) is not str:
        continue
    if type(row['protein name']) is str:
        protein_name = row['protein name']
        protein_cnt = 0
    if type(row['Familiy/genus']) is str and row['Familiy/genus'] != family_name:
        if records is not None:
            SeqIO.write(records, f"/zhouyuyang/project/ProteinFeatureEngineering/data/fp/{family_name}.fasta", "fasta")
            cnt += 1
            print(f"write {family_name}.fasta, cnt = {cnt}, protein_cnt = {len(records)}")
        family_name = row['Familiy/genus'].replace(' ', '-')
        protein_cnt += 1
        records = [SeqRecord(Seq(row['FP']), id=protein_name+'_'+str(protein_cnt), description=row['Familiy/genus'])]
    else:
        protein_cnt += 1
        records.append(SeqRecord(Seq(row['FP']), id=protein_name+'_'+str(protein_cnt), description=family_name))
# Out:
# write Herpesviridae.fasta, cnt = 1, protein_cnt = 62
# write Alpharetrovirus.fasta, cnt = 2, protein_cnt = 5
# write Betaretrovirus.fasta, cnt = 3, protein_cnt = 3
# write Deltaretrovirus.fasta, cnt = 4, protein_cnt = 16
# write Gammaretrovirus.fasta, cnt = 5, protein_cnt = 28
# write Hepatitis-B-virus.fasta, cnt = 6, protein_cnt = 9
# write Epstein–Barr-virus.fasta, cnt = 7, protein_cnt = 2
# write Lentivirus.fasta, cnt = 8, protein_cnt = 76
# write Spumaviruses.fasta, cnt = 9, protein_cnt = 1
# write Influenza-A-virus.fasta, cnt = 10, protein_cnt = 20
# write Influenza-B-virus.fasta, cnt = 11, protein_cnt = 10
# write Influenza-C-virus.fasta, cnt = 12, protein_cnt = 32
# write Isavirus.fasta, cnt = 13, protein_cnt = 1
# write Filoviridae.fasta, cnt = 14, protein_cnt = 15
# write Avulavirinae.fasta, cnt = 15, protein_cnt = 13
# write Orthoparamyxovirinae.fasta, cnt = 16, protein_cnt = 23
# write Rubulavirinae.fasta, cnt = 17, protein_cnt = 9
# write Pneumoviridae.fasta, cnt = 18, protein_cnt = 9
# write Coronavirus.fasta, cnt = 19, protein_cnt = 58
# write Togaviridae.fasta, cnt = 20, protein_cnt = 26
# write Flaviviridae.fasta, cnt = 21, protein_cnt = 55
# write Rhabdoviridae.fasta, cnt = 22, protein_cnt = 12
# write Baculoviridae.fasta, cnt = 23, protein_cnt = 2
# write Hepadnaviridae.fasta, cnt = 24, protein_cnt = 2
# write HAV.fasta, cnt = 25, protein_cnt = 1

# %%
fasta_root = "/zhouyuyang/project/ProteinFeatureEngineering/data/fasta/"

for file in os.listdir(fasta_root):
    path = fasta_root + file
    records = SeqIO.parse(path, "fasta")
    # print(f"Sequence number: {len(list(records))}")
    # print(file)
    
    df.loc[df["file name"]==file, 'number'] = len(list(records))
df.to_csv("/zhouyuyang/project/ProteinFeatureEngineering/data/all.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_973/2848630219.py in <module>
#       7     # print(file)
#       8
# ----> 9     df.loc[df["file name"]==file, 'number'] = len(list(records))
#      10 df.to_csv("/zhouyuyang/project/ProteinFeatureEngineering/data/all.csv", index=False)
#
# /usr/local/lib/python3.7/dist-packages/Bio/SeqIO/Interfaces.py in __next__(self)
#      70         """Return the next entry."""
#      71         try:
# ---> 72             return next(self.records)
#      73         except Exception:
#      74             if self.should_close_stream:
#
# /usr/local/lib/python3.7/dist-packages/Bio/SeqIO/FastaIO.py in iterate(self, handle)
#     244                     first_word = ""
#     245                 yield SeqRecord(
# --> 246                     Seq(sequence), id=first_word, name=first_word, description=title
#     247                 )
#     248
#
# /usr/local/lib/python3.7/dist-packages/Bio/SeqRecord.py in __init__(self, seq, id, name, description, dbxrefs, features, annotations, letter_annotations)
#     156     """
#     157
# --> 158     def __init__(
#     159         self,
#     160         seq,
#
# KeyboardInterrupt:

# %%
df['number'].tolist()
# Out:
# [732,
#  1128,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  5,
#  None,
#  None,
#  None,
#  None,
#  39,
#  None,
#  None,
#  60,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  20,
#  276,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  4698,
#  10508,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  68,
#  None,
#  299576,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  157,
#  192065,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  20179,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  380,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  167,
#  1,
#  9,
#  2,
#  87,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  7558,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  1,
#  1834,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  1,
#  1,
#  1,
#  518,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  7286,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  10384,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  4239,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  147525,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  10230,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  5,
#  235,
#  7,
#  24,
#  53,
#  10705,
#  None,
#  217,
#  13,
#  1456,
#  3676,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None,
#  None]

# %%
df.iloc[0]
# Out:
# Class                                            3
# Familiy/genus                        Herpesviridae
# protein name               Envelope_glycoprotein_H
# FP                            HGLASTLTRWAHYNALIRAF
# file name        Envelope_glycoprotein_H_HHV.fasta
# number                                         732
# Name: 0, dtype: object

# %%
df.to_csv("/zhouyuyang/project/ProteinFeatureEngineering/data/VFP.csv", index=False)

# %%
csv_base = "/zhouyuyang/project/ProteinFeatureEngineering/data/hmm_csv/"

# %%
import csv

# %%
csv_writer = csv.writer(open("/zhouyuyang/project/ProteinFeatureEngineering/data/scan_report.csv", "w"))
csv_writer.writerow(["file name", "hits", "number"])
# Out:
# 23

# %%
for file in os.listdir(csv_base):
    if not file.endswith(".csv"):
        continue
    path = csv_base + file
    df = pd.read_csv(path)
    hits = len(df)
    number = df['domain'].nunique()
    csv_writer.writerow([file, hits, number])

# %%
df = pd.read_csv("/zhouyuyang/project/ProteinFeatureEngineering/data/scan_report.csv")
print(f"total hits: {df['hits'].sum()}")
print(f"total number: {df['number'].sum()}")
# Out:
# total hits: 1180750
# total number: 10512

# %%
import os
